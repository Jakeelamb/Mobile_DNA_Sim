# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv('../Data/exon_ranges_summary.csv')
genome = data.iloc[:,1]
exon_genome_ratio = data.iloc[:,-1]
data.Species
# Out:
# 0             Accipiter_nisus.Accipiter_nisus_ver1.0.112
# 1                 Ailuropoda_melanoleuca.ASM200744v2.112
# 2                       Amazona_collaria.ASM394721v1.112
# 3                   Amphilophus_citrinellus.Midas_v5.112
# 4                  Amphiprion_ocellaris.ASM2253959v1.112
#                              ...
# 313    Xiphophorus_couchianus.Xiphophorus_couchianus-...
# 314       Xiphophorus_maculatus.X_maculatus-5.0-male.112
# 315              Zalophus_californianus.mZalCal1.pri.112
# 316    Zonotrichia_albicollis.Zonotrichia_albicollis-...
# 317         Zosterops_lateralis_melanops.ASM128173v1.112
# Name: Species, Length: 318, dtype: object

# %%
plt.scatter(genome, exon_genome_ratio, alpha = .5)

# %%
import numpy as np
import plotly.graph_objects as go

# Assuming 'genome' and 'exon_genome_ratio' are already defined
# Calculate num_TEs
data['num_TEs'] = np.log(0.5) / np.log(1 - data['exon_genome_ratio'])

# Create the scatter plot
fig = go.Figure(data=go.Scatter(
    x=data['genome'],
    y=data['num_TEs'],
    mode='markers',
    marker=dict(
        size=8,
        color=df['num_TEs'],  # color the markers based on num_TEs
        colorscale='Viridis',  # choose a colorscale
        opacity=0.5
    ),
    text=df.apply(lambda row: f"Species: {row['species']}<br>"
                              f"Genome Size: {row['genome']:.2f}<br>"
                              f"Exon/Genome Ratio: {row['exon_genome_ratio']:.4f}", axis=1),
    hoverinfo='text'
))

# Update the layout for better readability
fig.update_layout(
    title='Scatter Plot of Genome Size vs Number of TEs',
    xaxis_title='Genome Size',
    yaxis_title='Number of TEs (log scale)',
    template='plotly_white'
)

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'exon_genome_ratio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 6
#       2 import plotly.graph_objects as go
# ...

# %%
num_TEs = np.log(0.5) / np.log(1-exon_genome_ratio)


plt.scatter(genome, num_TEs, alpha = .3)

# %%
np.quantile(num_TEs, .9)
# Out:
# np.float64(424.2159401219614)

# %%
num_TEs[124]
# Out:
# np.float64(32.750947185648975)

# %%
num_TEs = np.log(0.5) / np.log(1-exon_genome_ratio)


plt.scatter(genome, num_TEs/genome, alpha = .3)

# %%
np.quantile(num_TEs/genome, .9)
# Out:
# np.float64(2.0517630666303543e-07)

# %%
(num_TEs/genome)[124]
# Out:
# np.float64(1.0565671295909988e-08)
